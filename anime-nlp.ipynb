# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/myanimelist-dataset/user-filtered.csv
#
# /kaggle/input/myanimelist-dataset/users-score-2023.csv
#
# /kaggle/input/myanimelist-dataset/anime-filtered.csv
#
# /kaggle/input/myanimelist-dataset/anime-dataset-2023.csv
#
# /kaggle/input/myanimelist-dataset/final_animedataset.csv
#
# /kaggle/input/myanimelist-dataset/users-details-2023.csv

# %% [markdown]
# # Thought process:
#
# ## Goal
# To make an anime recommendation system based on a synopsis description
#
# ### Steps:
# 1. Read datasets [X]
# 2. Clean datasets [X]
# 3. Get needed categories [X]
# 4. Fill and remove NaN [X]
# 5. Use nlp to tokenize synopsis [X]
# 6. Allow a description to be given and recommendations to be sent based on certain keywords [X]
# 7. Compare and contrast between other keyword extractors
# 8. Compare similarities
# 9. Select best option
# 10. Make web app

# %%
normal_df = pd.read_csv('/kaggle/input/myanimelist-dataset/anime-dataset-2023.csv')
filtered_df = pd.read_csv('/kaggle/input/myanimelist-dataset/anime-filtered.csv')
final_df = pd.read_csv('/kaggle/input/myanimelist-dataset/final_animedataset.csv')

# %%
# Get columns
print(normal_df.columns)
print(len(normal_df.columns))
print(filtered_df.columns)
print(len(filtered_df.columns))
print(final_df.columns)
print(len(final_df.columns))
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#
#       dtype='object')
#
# 24
#
# Index(['anime_id', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#
#        'sypnopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Producers',
#
#        'Licensors', 'Studios', 'Source', 'Duration', 'Rating', 'Ranked',
#
#        'Popularity', 'Members', 'Favorites', 'Watching', 'Completed',
#
#        'On-Hold', 'Dropped'],
#
#       dtype='object')
#
# 25
#
# Index(['username', 'anime_id', 'my_score', 'user_id', 'gender', 'title',
#
#        'type', 'source', 'score', 'scored_by', 'rank', 'popularity', 'genre'],
#
#       dtype='object')
#
# 13

# %%
normal_df.shape
# Out:
# (24905, 24)

# %%
normal_df.isna().sum()
# Out:
# anime_id        0
# Name            0
# English name    0
# Other name      0
# Score           0
# Genres          0
# Synopsis        0
# Type            0
# Episodes        0
# Aired           0
# Premiered       0
# Status          0
# Producers       0
# Licensors       0
# Studios         0
# Source          0
# Duration        0
# Rating          0
# Rank            0
# Popularity      0
# Favorites       0
# Scored By       0
# Members         0
# Image URL       0
# dtype: int64

# %%
normal_df['Synopsis'].head(10)
# Out:
# 0    Crime is timeless. By the year 2071, humanity ...
# 1    Another day, another bounty—such is the life o...
# 2    Vash the Stampede is the man with a $$60,000,0...
# 3    Robin Sena is a powerful craft user drafted in...
# 4    It is the dark century and the people are suff...
# 5    Shy, reserved, and small-statured, Deimon High...
# 6    Yuuta Takemoto, a sophomore at an arts college...
# 7    As the younger brother of Japanese soccer star...
# 8    Takumi Fujiwara finally joins Ryousuke and Kei...
# 9    Dr. Kenzou Tenma, an elite neurosurgeon recent...
# Name: Synopsis, dtype: object

# %%
normal_df['Name']
# Out:
# 0                           Cowboy Bebop
# 1        Cowboy Bebop: Tengoku no Tobira
# 2                                 Trigun
# 3                     Witch Hunter Robin
# 4                         Bouken Ou Beet
#                       ...
# 24900                        Wu Nao Monu
# 24901                Bu Xing Si: Yuan Qi
# 24902                        Di Yi Xulie
# 24903           Bokura no Saishuu Sensou
# 24904                     Shijuuku Nichi
# Name: Name, Length: 24905, dtype: object

# %% [markdown]
# # Data Cleaning
#
# Need to take out some useless information
#
# Columns to take out = Favorites, Image URL, Scored by, Members, Rank, Duration, Producers, Status, Studios, Licensors, Premiered, Aired,

# %%
normal_df.drop(columns=['Favorites', 'Image URL', 'Scored By', 'Members', 'Rank', 'Duration', 'Producers', 'Status', 'Licensors', 'Premiered', 'Aired'], inplace=True)

# %%
normal_df['Synopsis'] = normal_df['Synopsis'].replace("No description available for this anime", "Anime")

# %%
normal_df
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %% [markdown]
# # Clean and preprocess the synopsis text (remove punctuation, lowercase, etc.)

# %% [markdown]
# ## Stemming and Lemmatization

# %%
# !pip install unidecode
from unidecode import unidecode
from nltk.stem import PorterStemmer
# or from nltk.stem import WordNetLemmatizer
import re
import nltk
from nltk.corpus import stopwords

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# or lemmatizer = WordNetLemmatizer()

def clean_text(text):
    if pd.isna(text):
        return ""
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Tokenize
    tokens = nltk.word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    text = unidecode(text) # convert special characters to ASCII
    tokens = [stemmer.stem(token) for token in tokens]
    return ' '.join(tokens)
    
normal_df['Cleaned Synopsis'] = normal_df['Synopsis'].apply(clean_text)
# Out:
# ...
#
# ...
#
# ...
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.1 MB/s eta 0:00:00
#
# ...
#
# ...
#
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
#
# [nltk_data]   Package stopwords is already up-to-date!
#
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
#
# [nltk_data]   Package punkt is already up-to-date!

# %%
normal_df
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %% [markdown]
# # Use 3 Keyword Extraction methods and determine the one with the best accuracy

# %%
# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

def extract_keywords_tfidf(texts, top_n=10):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)
    feature_names = vectorizer.get_feature_names_out()
    
    keywords = []
    for i in range(len(texts)):
        tfidf_scores = tfidf_matrix[i].toarray()[0]
        sorted_indexes = tfidf_scores.argsort()[::-1]
        keywords.append([feature_names[idx] for idx in sorted_indexes[:top_n]])
    
    return keywords

# Apply to your cleaned synopses
normal_df['Keywords_tfidf'] = extract_keywords_tfidf(normal_df['Cleaned Synopsis'])

# %%
normal_df
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %% [markdown]
# # Process User input

# %%
def process_user_input(description):
    # Use the same cleaning function you used for the synopses
    cleaned_description = clean_text(description)
    
    # Extract keywords using the same method as before
    keywords = extract_keywords_tfidf([cleaned_description])[0]
    
    return cleaned_description, keywords

# Example usage:
# user_description = "A story about a high school student who finds a notebook that can kill people"
# cleaned_user_description, user_keywords = process_user_input(user_description)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Fit the vectorizer on your anime synopses
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = tfidf_vectorizer.fit_transform(normal_df['Cleaned Synopsis'])

def get_tfidf_vector(text):
    # Transform the new text using the fitted vectorizer
    return tfidf_vectorizer.transform([text])

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_recommendations_from_description(description, df=normal_df, top_n=10):
    # Process the user input
    cleaned_description, _ = process_user_input(description)
    # Get the TF-IDF vector for the description
    desc_vector = get_tfidf_vector(cleaned_description)
    # Calculate similarity with all anime synopses
    sim_scores = cosine_similarity(desc_vector, tfidf_matrix).flatten()
    # Get the indices of the top similar anime
    top_indices = sim_scores.argsort()[::-1][:top_n]
    # Return the top anime titles and their similarity scores
    recommendations = df.iloc[top_indices][['Name', 'Synopsis']]
    recommendations['Similarity'] = sim_scores[top_indices]
    
    return recommendations

# %%
user_description = "high school notebook"
recommendations = get_recommendations_from_description(user_description)
print(recommendations)
# Out:
#                                                  Name  \
#
# 14445                                      Promedicus
#
# 9446                     Shinken Seminar Koukou Kouza
#
# 5115          Ookiku Furikabutte: Natsu no Taikai-hen
#
# 14816  Choujigen Kakumei Anime: Dimension High School
#
# 93                        Sakigake!! Cromartie Koukou
#
# 4398                   Midoriyama Koukou Koushien-hen
#
# 779                          Joshikousei: Girl's High
#
# 4884           Shoujo Fight: Norainu-tachi no Odekake
#
# 22645                        Oretachi Majikou Destroy
#
# 6812                        Yajikita Gakuen Douchuuki
#
#
#
#                                                 Synopsis  Similarity
#
# 14445  Animated commercials for Promedicus, a cram sc...    0.584840
#
# 9446   Shinken Seminar Koukou Kouza is Benesse's corr...    0.523318
#
# 5115   Picking up where the original series left off,...    0.463325
#
# ...

# %% [markdown]
# # Trying Jaccard Similarity

# %%
from sklearn.feature_extraction.text import CountVectorizer

def get_recommendations_jaccard(description, df=normal_df, top_n=10):
    cleaned_description, _ = process_user_input(description)
    
    # Use CountVectorizer to get binary vectors
    vectorizer = CountVectorizer(binary=True)
    synopsis_vectors = vectorizer.fit_transform(df['Cleaned Synopsis'])
    desc_vector = vectorizer.transform([cleaned_description])
    
    # Calculate Jaccard similarities
    jaccard_sims = []
    for i in range(synopsis_vectors.shape[0]):
        intersection = np.logical_and(synopsis_vectors[i].toarray(), desc_vector.toarray())
        union = np.logical_or(synopsis_vectors[i].toarray(), desc_vector.toarray())
        jaccard_sim = np.sum(intersection) / np.sum(union)
        jaccard_sims.append(jaccard_sim)
    
    # Get top recommendations
    top_indices = np.argsort(jaccard_sims)[::-1][:top_n]
    recommendations = df.iloc[top_indices][['Name', 'Synopsis']]
    recommendations['Similarity'] = [jaccard_sims[i] for i in top_indices]
    
    return recommendations

# %%
# Compare results
user_description = "A story about hunters and boy looking for his father"
cosine_recommendations = get_recommendations_from_description(user_description)
jaccard_recommendations = get_recommendations_jaccard(user_description)

print("Cosine Similarity Recommendations:")
print(cosine_recommendations)
print("\nJaccard Similarity Recommendations:")
print(jaccard_recommendations)
# Out:
# Cosine Similarity Recommendations:
#
#                                             Name  \
#
# 6456                      Hunter x Hunter (2011)
#
# 9999                       Rainbow no Anime Bako
#
# 21123                                     Hunter
#
# 3684                     Bounty Hunter: The Hard
#
# 115                              Hunter x Hunter
#
# 8158   Hunter x Hunter Movie 2: The Last Mission
#
# 3485             Chuumon no Ooi Ryouriten (1991)
#
# 17743                         Hong Haier Chuanqi
#
# 12053                               Chicken Papa
#
# 10783                               Chichi to Ko
#
#
#
#                                                 Synopsis  Similarity
#
# 6456   Hunters devote themselves to accomplishing haz...    0.415269
#
# 9999   A boy looks into a box and sees a rainbow kale...    0.356482
#
# 21123  Hunter is looking for Gossip every night. A sh...    0.352974
#
# 3684   The story of "Hard", a bounty hunter living in...    0.334754
#
# ...

# %%
# Text Rank

# %%
# RAKE
